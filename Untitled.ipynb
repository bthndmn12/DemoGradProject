# %%
# Out:
# 403 - Forbidden

# %%
import numpy as np
from numpy import expand_dims
import pandas as pd
import json
import matplotlib.pyplot as plt
import seaborn as sns
import os
import sys



from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.applications import VGG16
from tensorflow.keras.models import Sequential


import keras
from keras import layers
from keras.wrappers.scikit_learn import KerasClassifier
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
from tensorflow.keras.optimizers import RMSprop,Adam
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import EarlyStopping

import tensorflow as tf
from tensorflow.keras import models, layers

# %%
with open('/media/shipsnet.json') as data_file:
    dataset = json.load(data_file)
shipsnet= pd.DataFrame(dataset)
shipsnet.head()
# Out:
#                                                 data  labels  \
# 0  [82, 89, 91, 87, 89, 87, 86, 86, 86, 86, 84, 8...       1
# 1  [76, 75, 67, 62, 68, 72, 73, 73, 68, 69, 69, 6...       1
# 2  [125, 127, 129, 130, 126, 125, 129, 133, 132, ...       1
# 3  [102, 99, 113, 106, 96, 102, 105, 105, 103, 10...       1
# 4  [78, 76, 74, 78, 79, 79, 79, 82, 86, 85, 83, 8...       1
#
#                                    locations             scene_ids
# 0    [-118.2254694333423, 33.73803725920789]  20180708_180909_0f47
# 1    [-122.33222866289329, 37.7491755586813]  20170705_180816_103e
# 2  [-118.14283073363218, 33.736016066914175]  20180712_211331_0f06
# 3   [-122.34784341495181, 37.76648707436548]  20170609_180756_103a
# 4   [-122.34852408322172, 37.75878462398653]  20170515_180653_1007

# %%
shipsnet.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4000 entries, 0 to 3999
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   data       4000 non-null   object
#  1   labels     4000 non-null   int64
#  2   locations  4000 non-null   object
#  3   scene_ids  4000 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 125.1+ KB

# %%
shipsnet = shipsnet[["data", "labels"]]
shipsnet.head()
# Out:
#                                                 data  labels
# 0  [82, 89, 91, 87, 89, 87, 86, 86, 86, 86, 84, 8...       1
# 1  [76, 75, 67, 62, 68, 72, 73, 73, 68, 69, 69, 6...       1
# 2  [125, 127, 129, 130, 126, 125, 129, 133, 132, ...       1
# 3  [102, 99, 113, 106, 96, 102, 105, 105, 103, 10...       1
# 4  [78, 76, 74, 78, 79, 79, 79, 82, 86, 85, 83, 8...       1

# %%
len(shipsnet["data"].iloc[0])
# Out:
# 19200

# %%
ship_images = shipsnet["labels"].value_counts()[0]
no_ship_images = shipsnet["labels"].value_counts()[1]
print("Number of the ship_images :{}".format(ship_images),"\n")
print("Number of the no ship_images :{}".format(no_ship_images))
# Out:
# Number of the ship_images :3000
#
# Number of the no ship_images :1000

# %%
# Turning the json information into numpy array and then assign it as x and y variables
x = np.array(dataset['data']).astype('uint8')
y = np.array(dataset['labels']).astype('uint8')

# %%
x.shape
# Out:
# (4000, 19200)

# %%
y.shape
# Out:
# (4000,)

# %%
x_reshaped = x.reshape([-1, 3, 80, 80])

# %%
x_reshaped.shape
# Out:
# (4000, 3, 80, 80)

# %%
x_reshaped = x.reshape([-1, 3, 80, 80]).transpose([0,2,3,1])
x_reshaped.shape
# Out:
# (4000, 80, 80, 3)

# %%
y_reshaped = to_categorical(y, num_classes=2)

y_reshaped.shape
# Out:
# (4000, 2)

# %%
y_reshaped
# Out:
# array([[0., 1.],
#        [0., 1.],
#        [0., 1.],
#        ...,
#        [1., 0.],
#        [1., 0.],
#        [1., 0.]], dtype=float32)

# %%
image_ship = x_reshaped[y==1]
image_no_ship = x_reshaped[y==0]

def plot(a,b):
    
    plt.figure(figsize=(15, 15))
    for i, k in enumerate(range(1,9)):
        if i < 4:
            plt.subplot(2,4,k)
            plt.title('Not A Ship')
            plt.imshow(image_no_ship[i])
            plt.axis("off")
        else:
            plt.subplot(2,4,k)
            plt.title('Ship')
            plt.imshow(image_ship[i])
            plt.axis("off")
            
    plt.subplots_adjust(bottom=0.3, top=0.7, hspace=0.25)

#Implementation of the function 

plot(image_no_ship, image_ship)

# %%
x_reshaped = x_reshaped / 255

# %%
x_reshaped[0][0][0]
# Out:
# array([0.32156863, 0.36862745, 0.31372549])

# %%
n_bins = 30
plt.hist(x_reshaped[y == 0][0][:,:,0].flatten(), bins = n_bins, lw = 0, color = 'r', alpha = 0.5);
plt.hist(x_reshaped[y == 0][0][:,:,1].flatten(), bins = n_bins, lw = 0, color = 'g', alpha = 0.5);
plt.hist(x_reshaped[y == 0][0][:,:,2].flatten(), bins = n_bins, lw = 0, color = 'b', alpha = 0.5);
plt.ylabel('Count', fontweight = "bold")
plt.xlabel('Pixel Intensity', fontweight = "bold")
plt.title("Histogram of normalized data")
plt.show()

# %%
x_train_1, x_test, y_train_1, y_test = train_test_split(x_reshaped, y_reshaped,
                                                        test_size = 0.20, random_state = 42)


x_train, x_val, y_train, y_val = train_test_split(x_train_1, y_train_1, 
                                                  test_size = 0.25, random_state = 42)


# X2_train = tf.keras.applications.vgg16.preprocess_input(x_train)
# X2_test = tf.keras.applications.vgg16.preprocess_input(x_test)

print("x_train shape",x_train.shape)
print("x_test shape",x_test.shape)
print("y_train shape",y_train.shape)
print("y_test shape",y_test.shape)
print("x_train shape",x_val.shape)
print("y_test shape",y_val.shape)

# print("X2_train shape",X2_train.shape)
# print("X2_test shape",X2_test.shape)
# Out:
# x_train shape (2400, 80, 80, 3)
# x_test shape (800, 80, 80, 3)
# y_train shape (2400, 2)
# y_test shape (800, 2)
# x_train shape (800, 80, 80, 3)
# y_test shape (800, 2)

# %%
X_train2_val, X_test2, y_train2_val, y_test2 = train_test_split(x_reshaped,y, test_size=0.1, random_state=5, shuffle=True, stratify=y)
X_train2, X_val2, y_train2, y_val2 = train_test_split(X_train2_val, y_train2_val, test_size=0.1)
print(x_reshaped.shape, y.shape)
print(X_train2.shape, y_train2.shape)
print(X_val2.shape, y_val2.shape)
print(X_test2.shape, y_test2.shape)
# Out:
# (4000, 80, 80, 3) (4000,)
# (3240, 80, 80, 3) (3240,)
# (360, 80, 80, 3) (360,)
# (400, 80, 80, 3) (400,)

# %%
from keras import callbacks
model3 = Sequential()
model3.add(Conv2D(32, (3, 3), padding='same', input_shape=(80, 80, 3), activation='relu'))
model3.add(MaxPool2D(pool_size=(2, 2))) 
model3.add(Dropout(0.25))
model3.add(Conv2D(32, (3, 3), padding='same', input_shape=(80, 80, 3), activation='relu'))
model3.add(MaxPool2D(pool_size=(2, 2))) 
model3.add(Dropout(0.25))
model3.add(Conv2D(32, (3, 3), padding='same', input_shape=(80, 80, 3), activation='relu'))
model3.add(MaxPool2D(pool_size=(2, 2))) 
model3.add(Dropout(0.25))
model3.add(Conv2D(32, (3, 3), padding='same', input_shape=(80, 80, 3), activation='relu'))
model3.add(MaxPool2D(pool_size=(2, 2))) 
model3.add(Dropout(0.25))
model3.add(Flatten(input_shape=[80, 80, 3]))
model3.add(Dense(200, activation='relu'))
model3.add(Dense(150, activation='relu'))
model3.add(Dense(2, activation='sigmoid'))

model3.compile(loss="categorical_crossentropy", optimizer='Adam', metrics=['accuracy'])
earlystopping = callbacks.EarlyStopping(monitor ="val_loss", 
                                        mode ="min", patience = 10, 
                                        restore_best_weights = True)

history = model3.fit(x_train, y_train, epochs = 100, validation_data=(x_val, y_val), callbacks = [earlystopping])
# Out:
# Epoch 1/100
# 75/75 [==============================] - 2s 14ms/step - loss: 0.3905 - accuracy: 0.8258 - val_loss: 0.2723 - val_accuracy: 0.9038
# Epoch 2/100
# 75/75 [==============================] - 1s 9ms/step - loss: 0.2289 - accuracy: 0.9075 - val_loss: 0.2174 - val_accuracy: 0.9325
# Epoch 3/100
# 75/75 [==============================] - 1s 10ms/step - loss: 0.1745 - accuracy: 0.9350 - val_loss: 0.1787 - val_accuracy: 0.9375
# Epoch 4/100
# 75/75 [==============================] - 1s 9ms/step - loss: 0.1186 - accuracy: 0.9533 - val_loss: 0.1491 - val_accuracy: 0.9425
# Epoch 5/100
# 75/75 [==============================] - 1s 9ms/step - loss: 0.0891 - accuracy: 0.9704 - val_loss: 0.0909 - val_accuracy: 0.9712
# Epoch 6/100
# 75/75 [==============================] - 1s 10ms/step - loss: 0.0667 - accuracy: 0.9767 - val_loss: 0.1083 - val_accuracy: 0.9675
# Epoch 7/100
# ...

# %%
model3.summary()
# Out:
# Model: "sequential_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_12 (Conv2D)          (None, 80, 80, 32)        896
#
#  max_pooling2d_12 (MaxPoolin  (None, 40, 40, 32)       0
#  g2D)
#
#  dropout_11 (Dropout)        (None, 40, 40, 32)        0
#
#  conv2d_13 (Conv2D)          (None, 40, 40, 32)        9248
#
#  max_pooling2d_13 (MaxPoolin  (None, 20, 20, 32)       0
#  g2D)
#
#  dropout_12 (Dropout)        (None, 20, 20, 32)        0
#
#  conv2d_14 (Conv2D)          (None, 20, 20, 32)        9248
#
#  max_pooling2d_14 (MaxPoolin  (None, 10, 10, 32)       0
#  g2D)
#
#  dropout_13 (Dropout)        (None, 10, 10, 32)        0
#
#  conv2d_15 (Conv2D)          (None, 10, 10, 32)        9248
#
#  max_pooling2d_15 (MaxPoolin  (None, 5, 5, 32)         0
#  g2D)
#
#  dropout_14 (Dropout)        (None, 5, 5, 32)          0
#
#  flatten_18 (Flatten)        (None, 800)               0
#
# ...

# %%
model3.evaluate(x_test, y_test)
# Out:
# 25/25 [==============================] - 0s 6ms/step - loss: 0.0637 - accuracy: 0.9875
# [0.06365302205085754, 0.987500011920929]

# %%
from keras import callbacks
model = Sequential()
model.add(VGG16(include_top=False, input_shape=(80, 80, 3)))
model.add(Flatten(input_shape=[80, 80, 3]))
model.add(Dense(200, activation='relu'))
model.add(Dense(150, activation='relu'))
model.add(Dense(2, activation='sigmoid'))

model.compile(loss=tf.keras.losses.BinaryCrossentropy(), optimizer=tf.keras.optimizers.experimental.SGD(learning_rate=0.0001), metrics=['accuracy'])
earlystopping = callbacks.EarlyStopping(monitor ="val_loss", 
                                        mode ="min", patience = 10, 
                                        restore_best_weights = True)

history = model.fit(x_train, y_train, epochs = 10, validation_data=(x_val, y_val), callbacks = [earlystopping])
# Out:
# Epoch 1/10
# 75/75 [==============================] - 8s 89ms/step - loss: 0.5904 - accuracy: 0.7533 - val_loss: 0.5675 - val_accuracy: 0.7513
# Epoch 2/10
# 75/75 [==============================] - 6s 83ms/step - loss: 0.5467 - accuracy: 0.7533 - val_loss: 0.5290 - val_accuracy: 0.7513
# Epoch 3/10
# 75/75 [==============================] - 6s 84ms/step - loss: 0.5095 - accuracy: 0.7533 - val_loss: 0.4937 - val_accuracy: 0.7513
# Epoch 4/10
# 75/75 [==============================] - 6s 84ms/step - loss: 0.4744 - accuracy: 0.7533 - val_loss: 0.4598 - val_accuracy: 0.7513
# Epoch 5/10
# 75/75 [==============================] - 6s 84ms/step - loss: 0.4401 - accuracy: 0.7533 - val_loss: 0.4261 - val_accuracy: 0.7513
# Epoch 6/10
# 75/75 [==============================] - 6s 84ms/step - loss: 0.4059 - accuracy: 0.7579 - val_loss: 0.3927 - val_accuracy: 0.7625
# Epoch 7/10
# ...

# %%
model.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  vgg16 (Functional)          (None, 2, 2, 512)         14714688
#
#  flatten_11 (Flatten)        (None, 2048)              0
#
#  dense_33 (Dense)            (None, 200)               409800
#
#  dense_34 (Dense)            (None, 150)               30150
#
#  dense_35 (Dense)            (None, 2)                 302
#
# ...
# Total params: 15,154,940
# Trainable params: 15,154,940
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.evaluate(x_test, y_test)
# Out:
# 25/25 [==============================] - 1s 28ms/step - loss: 0.2692 - accuracy: 0.9087
# [0.26924896240234375, 0.9087499976158142]

# %%
pd.DataFrame(history.history).plot();

# %%
prediction = model3.predict(x_test)
pd.Series(prediction[15], index=["Not A Ship", "Ship"])
# Out:
# 25/25 [==============================] - 0s 5ms/step
# Not A Ship    0.954789
# Ship          0.090459
# dtype: float32

# %%
plt.imshow(x_test[15])
#plt.imshow((x_test[4] * 255).astype(np.uint8))
plt.axis("off")

plt.show()

# %%
pd.DataFrame(history.history).plot();

# %%
prediction = model.predict(x_test)
pd.Series(prediction[0], index=["Not A Ship", "Ship"])
# Out:
# 25/25 [==============================] - 1s 28ms/step
# Not A Ship    0.257384
# Ship          0.538990
# dtype: float32

# %%
plt.imshow(x_test[0])
#plt.imshow((x_test[4] * 255).astype(np.uint8))
plt.axis("off")

plt.show()

# %%
predicted_data = pd.DataFrame(prediction, columns=["Not A Ship", "Ship"])
predicted_data.head(5)
# Out:
#    Not A Ship      Ship
# 0    0.002592  0.997778
# 1    0.999902  0.000178
# 2    0.004146  0.997859
# 3    0.999963  0.000014
# 4    0.999998  0.000051

# %%
from keras import callbacks
model2 = Sequential()
model2.add(VGG16(include_top=False, input_shape=(80, 80, 3)))
model2.add(Flatten(input_shape=[80, 80, 3]))
model2.add(Dense(200, activation='elu'))
model2.add(Dense(150, activation='elu'))
model2.add(Dense(2, activation='sigmoid'))

model2.compile(loss=tf.keras.losses.BinaryCrossentropy(), optimizer=tf.keras.optimizers.experimental.SGD(learning_rate=0.000314), metrics=['accuracy'])
earlystopping = callbacks.EarlyStopping(monitor ="val_loss", 
                                        mode ="min", patience = 10, 
                                        restore_best_weights = True)

history = model2.fit(x_train, y_train, epochs = 10, validation_data=(x_val, y_val), callbacks = [earlystopping])
# Out:
# Epoch 1/10
# 75/75 [==============================] - 9s 98ms/step - loss: 0.4540 - accuracy: 0.8379 - val_loss: 0.3250 - val_accuracy: 0.9325
# Epoch 2/10
# 75/75 [==============================] - 7s 93ms/step - loss: 0.2439 - accuracy: 0.9492 - val_loss: 0.2001 - val_accuracy: 0.9488
# Epoch 3/10
# 75/75 [==============================] - 6s 85ms/step - loss: 0.1585 - accuracy: 0.9588 - val_loss: 0.1485 - val_accuracy: 0.9575
# Epoch 4/10
# 75/75 [==============================] - 6s 86ms/step - loss: 0.1192 - accuracy: 0.9683 - val_loss: 0.1208 - val_accuracy: 0.9638
# Epoch 5/10
# 75/75 [==============================] - 6s 86ms/step - loss: 0.0956 - accuracy: 0.9717 - val_loss: 0.1009 - val_accuracy: 0.9675
# Epoch 6/10
# 75/75 [==============================] - 6s 87ms/step - loss: 0.0795 - accuracy: 0.9758 - val_loss: 0.0871 - val_accuracy: 0.9712
# Epoch 7/10
# ...

# %%
model2.summary()
# Out:
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  vgg16 (Functional)          (None, 2, 2, 512)         14714688
#
#  flatten_15 (Flatten)        (None, 2048)              0
#
#  dense_49 (Dense)            (None, 200)               409800
#
#  dense_50 (Dense)            (None, 150)               30150
#
#  dense_51 (Dense)            (None, 2)                 302
#
# ...
# Total params: 15,154,940
# Trainable params: 15,154,940
# Non-trainable params: 0
# _________________________________________________________________

# %%
model2.evaluate(x_test, y_test)
# Out:
# 25/25 [==============================] - 1s 29ms/step - loss: 0.0392 - accuracy: 0.9912
# [0.03919513523578644, 0.9912499785423279]

# %%
pd.DataFrame(history.history).plot();

# %%
prediction = model.predict(x_test)
for i in range(10):
  print(i,pd.Series(prediction[i], index=["Not A Ship", "Ship"]))
# Out:
# 25/25 [==============================] - 1s 28ms/step
# 0 Not A Ship    0.257384
# Ship          0.538990
# dtype: float32
# 1 Not A Ship    0.893838
# Ship          0.052826
# dtype: float32
# 2 Not A Ship    0.420195
# Ship          0.542865
# dtype: float32
# 3 Not A Ship    0.784533
# Ship          0.143954
# dtype: float32
# 4 Not A Ship    0.820187
# Ship          0.232853
# dtype: float32
# 5 Not A Ship    0.436535
# Ship          0.643467
# dtype: float32
# 6 Not A Ship    0.936104
# Ship          0.039197
# dtype: float32
# 7 Not A Ship    0.288734
# Ship          0.665354
# dtype: float32
# 8 Not A Ship    0.405032
# Ship          0.511396
# dtype: float32
# 9 Not A Ship    0.614045
# Ship          0.261119
# dtype: float32

# %%
prediction = model2.predict(x_test)
for i in range(10):
  print(i,pd.Series(prediction[i], index=["Not A Ship", "Ship"]))
# Out:
# 25/25 [==============================] - 1s 27ms/step
# 0 Not A Ship    0.003747
# Ship          0.979579
# dtype: float32
# 1 Not A Ship    0.996653
# Ship          0.000755
# dtype: float32
# 2 Not A Ship    0.010577
# Ship          0.978217
# dtype: float32
# 3 Not A Ship    0.982659
# Ship          0.009610
# dtype: float32
# 4 Not A Ship    0.987522
# Ship          0.005227
# dtype: float32
# 5 Not A Ship    0.016446
# Ship          0.970276
# dtype: float32
# 6 Not A Ship    0.998380
# Ship          0.000907
# dtype: float32
# 7 Not A Ship    0.004394
# Ship          0.990305
# dtype: float32
# 8 Not A Ship    0.011171
# Ship          0.979546
# dtype: float32
# 9 Not A Ship    0.022519
# Ship          0.932014
# dtype: float32

# %%
from PIL import Image
images = []
for img_path in dataset['data']:
  img = Image.open('/media/lb_1.png')
  images.append(img)

a = np.array(img).astype('uint8')
a_reshaped = a.reshape([-1, 3, 80, 80])
a_reshaped = a.reshape([-1, 3, 80, 80]).transpose([0,2,3,1])
a.shape
a_reshaped.shape
# Out:
# (1, 80, 80, 3)

# %%
prediction = model2.predict(x_test)
print(i,pd.Series(prediction[0], index=["Not A Ship", "Ship"]))
# Out:
# 25/25 [==============================] - 1s 27ms/step
# 9 Not A Ship    0.003747
# Ship          0.979579
# dtype: float32

# %%
prediction = model.predict(a_reshaped)
pd.Series(prediction[0], index=["Not A Ship", "Ship"])
# Out:
# 1/1 [==============================] - 0s 132ms/step
# Not A Ship    0.981732
# Ship          0.030429
# dtype: float32

# %%
image = Image.open(r'/media/sfbay_1.png')
pix = image.load()

# %%
n_spectrum = 3
width = image.size[0]
height = image.size[1]
  # creat vector
picture_vector = []
for chanel in range(n_spectrum):
    for y in range(height):
        for x in range(width):
            picture_vector.append(pix[x, y][chanel])
picture_vector = np.array(picture_vector).astype('uint8')
picture_tensor = picture_vector.reshape([n_spectrum, height, width]).transpose(1, 2, 0)
plt.figure(1, figsize = (15, 30))
plt.subplot(3, 1, 1)
plt.imshow(picture_tensor)
plt.show()

# %%
picture_tensor = picture_tensor.transpose(2,0,1)
  # Search on the image
def cutting(x, y):
    area_study = np.arange(3*80*80).reshape(3, 80, 80)
    for i in range(80):
        for j in range(80):
            area_study[0][i][j] = picture_tensor[0][y+i][x+j]
            area_study[1][i][j] = picture_tensor[1][y+i][x+j]
            area_study[2][i][j] = picture_tensor[2][y+i][x+j]
    area_study = area_study.reshape([-1, 3, 80, 80])
    area_study = area_study.transpose([0,2,3,1])
    area_study = area_study / 255
    sys.stdout.write('\rX:{0} Y:{1}  '.format(x, y))
    return area_study
def not_near(x, y, s, coordinates):
    result = True
    for e in coordinates:
        if x+s > e[0][0] and x-s < e[0][0] and y+s > e[0][1] and y-s < e[0][1]:
            result = False
    return result
    
def show_ship(x, y, acc, thickness=5):   
    for i in range(80):
        for ch in range(3):
            for th in range(thickness):
                picture_tensor[ch][y+i][x-th] = -1
    for i in range(80):
        for ch in range(3):
            for th in range(thickness):
                picture_tensor[ch][y+i][x+th+80] = -1
    for i in range(80):
        for ch in range(3):
             for th in range(thickness):
                picture_tensor[ch][y-th][x+i] = -1
    for i in range(80):
        for ch in range(3):
             for th in range(thickness):
                 picture_tensor[ch][y+th+80][x+i] = -1

# %%
step = 10; coordinates = []
for y in range(int((height-(80-step))/step)):
    for x in range(int((width-(80-step))/step) ):
        area = cutting(x*step, y*step)
        result = model3.predict(area)
        if result[0][1] > 0.90 and not_near(x*step,y*step, 88, coordinates):
            coordinates.append([[x*step, y*step], result])
            print(result)
            plt.imshow(area[0])
            plt.show()
# Out:
# Streaming output truncated to the last 5000 lines.
# ...
# 1/1 [==============================] - 0s 26ms/step
# ...
#       6         if result[0][1] > 0.90 and not_near(x*step,y*step, 88, coordinates):
#       7             coordinates.append([[x*step, y*step], result])
#
# /usr/local/lib/python3.8/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      62     filtered_tb = None
#      63     try:
# ---> 64       return fn(*args, **kwargs)
#      65     except Exception as e:  # pylint: disable=broad-except
#      66       filtered_tb = _process_traceback_frames(e.__traceback__)
#
# /usr/local/lib/python3.8/dist-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    2000               stacklevel=2)
#    2001
# -> 2002       data_handler = data_adapter.get_data_handler(
#    2003           x=x,
#    2004           batch_size=batch_size,
#
# ...

# %%
if result[0][1] > 0.01 and not_near(x*step,y*step, 88, coordinates):
  coordinates.append([[x*step, y*step], result])
  print(result)
  plt.imshow(area[0])
  plt.show()

# %%
predicted_data = pd.DataFrame(prediction, columns=["Not A Ship", "Ship"])
predicted_data.head()
# Out:
#    Not A Ship  Ship
# 0    0.000000   1.0
# 1    1.000000   0.0
# 2    0.225238   1.0
# Error: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.

# %%
input_shape2 = (80,80,3)
# CNN Layers

model3 = models.Sequential()
model3.add(layers.Conv2D(16, (3, 3), activation="relu", padding='same', input_shape=input_shape2))
model3.add(layers.MaxPooling2D((2, 2)))
model3.add(layers.Conv2D(32, (3, 3), activation="relu"))
model3.add(layers.MaxPooling2D((2, 2)))
model3.add(layers.Conv2D(32, (3, 3), activation="relu"))
model3.add(layers.MaxPooling2D((2, 2)))
model3.add(layers.Conv2D(64, (3, 3), activation="relu"))
model3.add(layers.MaxPooling2D((2, 2)))

# ANN Layers
model3.add(layers.GlobalAveragePooling2D())
model3.add(layers.Dense(1024, activation="relu"))
model3.add(layers.Dropout(0.2))
model3.add(layers.Dense(512, activation="relu"))
model3.add(layers.Dropout(0.2))
model3.add(layers.Dense(128, activation="relu"))
model3.add(layers.Dropout(0.2))
model3.add(layers.Dense(1, activation='sigmoid'))

model3.summary()
# Out:
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 80, 80, 16)        448
#
#  max_pooling2d (MaxPooling2D  (None, 40, 40, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 38, 38, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 19, 19, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 17, 17, 32)        9248
#
#  max_pooling2d_2 (MaxPooling  (None, 8, 8, 32)         0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 6, 6, 64)          18496
#
#  max_pooling2d_3 (MaxPooling  (None, 3, 3, 64)         0
#  2D)
#
#  global_average_pooling2d (G  (None, 64)               0
#  lobalAveragePooling2D)
#
#  dense_39 (Dense)            (None, 1024)              66560
#
#  dropout (Dropout)           (None, 1024)              0
#
#  dense_40 (Dense)            (None, 512)               524800
#
# ...

# %%
model3.compile(optimizer='adam',
            loss='binary_crossentropy',
            metrics=['accuracy']
            )

callback = tf.keras.callbacks.EarlyStopping(monitor='accuracy', patience=3, restore_best_weights=True)

# %%
history = model3.fit(
   X_train2, 
    y_train2, 
    epochs = 30,  
    validation_data = (X_val2, y_val2),
    batch_size = 64,
    callbacks=[callback]
)
# Out:
# Epoch 1/30
# 51/51 [==============================] - 1s 19ms/step - loss: 0.0499 - accuracy: 0.9802 - val_loss: 0.0859 - val_accuracy: 0.9694
# Epoch 2/30
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0528 - accuracy: 0.9799 - val_loss: 0.0827 - val_accuracy: 0.9833
# Epoch 3/30
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0543 - accuracy: 0.9787 - val_loss: 0.0562 - val_accuracy: 0.9833
# Epoch 4/30
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0453 - accuracy: 0.9843 - val_loss: 0.1079 - val_accuracy: 0.9694
# Epoch 5/30
# 51/51 [==============================] - 1s 11ms/step - loss: 0.0495 - accuracy: 0.9824 - val_loss: 0.0581 - val_accuracy: 0.9722
# Epoch 6/30
# 51/51 [==============================] - 1s 12ms/step - loss: 0.0318 - accuracy: 0.9904 - val_loss: 0.0871 - val_accuracy: 0.9750
# Epoch 7/30
# ...

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.figure(figsize=(10,10))
plt.subplot(2, 1, 1)
plt.plot(acc, label='Training Accuracy')
plt.plot(val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.ylabel('Accuracy')
plt.ylim([0.96,1])
plt.title('Training and Validation Accuracy')

plt.subplot(2, 1, 2)
plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.ylabel('Loss')
plt.ylim([0,0.15])
plt.title('Training and Validation Loss')
plt.xlabel('epoch')
plt.show()

# %%
model3.evaluate(X_test2, y_test2)
# Out:
# 13/13 [==============================] - 0s 15ms/step - loss: 0.1160 - accuracy: 0.9575
# [0.1160234808921814, 0.9574999809265137]

# %%
y_pred = model3.predict(X_test2)
y_pred[:2]
# Out:
# 13/13 [==============================] - 0s 5ms/step
# array([[1.1639688e-09],
#        [1.1990942e-07]], dtype=float32)

# %%
yp = []
for element in y_pred:
    if element > 0.49:
        yp.append(1)
    else:  
        yp.append(0)

yp[:5]
# Out:
# [0, 0, 0, 0, 0]

# %%
from sklearn.metrics import confusion_matrix, classification_report

print(classification_report(y_test2, yp, labels=[0, 1]))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97       300
#            1       0.86      0.99      0.92       100
#
#     accuracy                           0.96       400
#    macro avg       0.93      0.97      0.95       400
# weighted avg       0.96      0.96      0.96       400

# %%
cm = confusion_matrix(y_test2, yp)
plt.figure(figsize= (10,7))
sns.heatmap(cm, annot=True, fmt='d')
plt.xlabel('Predicted')
plt.ylabel('True')
# Out:
# Text(69.0, 0.5, 'True')

# %%
import tensorflow as tf
import numpy as np
import cv2

# Load the YOLO model
model = tf.keras.models.load_model('yolo_model.h5')

# Load the satellite image
image = tf.keras.preprocessing.image.load_img('satellite_image.jpg')

# Preprocess the image for the YOLO model
image = tf.keras.preprocessing.image.img_to_array(image)
image = tf.keras.applications.mobilenet_v2.preprocess_input(image)
image = np.expand_dims(image, axis=0)

# Use the YOLO model to predict the bounding boxes and class labels of ships in the image
boxes, classes, scores = model.predict(image)

# Extract the bounding boxes and class labels for ships in the image
ship_boxes = boxes[classes == 'ship']
ship_labels = classes[classes == 'ship']

# Loop through the bounding boxes and draw them on the image
for box, label in zip(ship_boxes, ship_labels):
  x1, y1, x2, y2 = box
  cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 0), 2)

# Show the image with the detected ships
cv2.imshow('Satellite Image with Ships', image)
cv2.waitKey(0)

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 11766269228523269262
# xla_global_id: -1
# ]

# %%
print(tf.config.list_physical_devices('GPU'))
# Out:
# []

# %%
from tensorflow.python.client import device_lib

device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 8611671980890755466
#  xla_global_id: -1]

# %%
tf.test.is_gpu_available()
# Out:
# WARNING:tensorflow:From C:\Users\admin\AppData\Local\Temp\ipykernel_12628\337460670.py:1: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# False

# %%
tf.config.list_physical_devices('GPU')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3112\1561540886.py in <module>
# ----> 1 tf.config.list_physical_devices('GPU')
#
# NameError: name 'tf' is not defined
